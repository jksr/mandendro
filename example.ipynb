# %%
from ManDendro import ManDendro

# %%
import scipy.cluster.hierarchy as sch
import numpy as np

# %%
dists = np.array([662., 877., 255., 412., 996., 295., 468., 268.,
                  400., 754., 564., 138., 219., 869., 669.])
Z = sch.linkage(dists, 'complete')
labels = [f'c{x}' for x in range(len(Z)+1)]
colors = ['#7fc97f']*3+['#beaed4']*2+['#fdc086']
labelcolors = dict(zip(labels,colors))

# %%
mdendro = ManDendro(Z,labels,labelcolors)
mdendro.plot_dendro()
# Out:
# <AxesSubplot:>

# %%
mdendro.switch_node(8)
mdendro.plot_dendro()
# Out:
# <AxesSubplot:>

# %%
mdendro.switch_node(8)
mdendro.plot_dendro()
# Out:
# <AxesSubplot:>

# %%
mdendro.switch_node(10)
mdendro.plot_dendro()
# Out:
# <AxesSubplot:>

# %%
mdendro.undo()
mdendro.plot_dendro()
# Out:
# <AxesSubplot:>

# %%
mdendro.switch_node(8)
mdendro.plot_dendro()
# Out:
# <AxesSubplot:>

# %%
mdendro.get_current_linkage()
# Out:
# array([[  2.,   5., 138.,   2.],
#        [  3.,   4., 219.,   2.],
#        [  6.,   1., 400.,   3.],
#        [  0.,   7., 412.,   3.],
#        [  8.,   9., 996.,   6.]])
